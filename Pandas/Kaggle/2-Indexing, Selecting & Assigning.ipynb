# %%
import pandas as pd

reviews = pd.read_csv("wine reviews.csv", index_col=0)
reviews
# Out:
#                        Brand  \
# Sl.No.
# 1                      Gallo
# 2            Fresh Craft Co.
# ...                      ...
# 2889    Vintage Wine Estates
# 2890    Vintage Wine Estates
#
#                                                      Name  \
# Sl.No.
# 1              Ecco Domani174 Pinot Grigio - 750ml Bottle
# 2        Fresh Craft174 Mango Citrus - 4pk / 250ml Bottle
# ...                                                   ...
# 2889    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2890    Vintage Wine Estates Kevin O'Leary's Select Re...
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                  1.0
# 2       2018-01-09T17:31:52Z                 True                  NaN
# ...                      ...                  ...                  ...
# 2889    2017-11-15T17:05:21Z                  NaN                  NaN
# ...

# %%
reviews.iloc[:5, 2]
# Out:
# Sl.No.
# 1    2018-01-09T13:24:04Z
# 2    2018-01-09T17:31:52Z
# 3    2018-01-09T17:31:51Z
# 4    2017-10-04T18:03:12Z
# 5    2018-01-10T18:06:29Z
# Name: Reviews Date Added, dtype: object

# %%
reviews.iloc[4:6, 1]
# Out:
# Sl.No.
# 5              Pink Moscato - 3l Bottle - Wine Cube153
# 6    Beck's174 Non Alcoholic Beer - 6pk / 12oz Bottles
# Name: Name, dtype: object

# %%
reviews.iloc[[6, 88, 345], 0]
# Out:
# Sl.No.
# 7                Gallo
# 89            Jim Beam
# 346    Master of Mixes
# Name: Brand, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#                        Brand  \
# Sl.No.
# 2886    Vintage Wine Estates
# 2887    Vintage Wine Estates
# 2888    Vintage Wine Estates
# 2889    Vintage Wine Estates
# 2890    Vintage Wine Estates
#
#                                                      Name  \
# Sl.No.
# 2886    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2887    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2888    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2889    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2890    Vintage Wine Estates Kevin O'Leary's Select Re...
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 2886    2018-01-02T20:20:02Z                  NaN                  NaN
# 2887    2018-01-02T20:20:02Z                  NaN                  NaN
# 2888    2017-12-16T08:00:39Z                  NaN                  NaN
# 2889    2017-11-15T17:05:21Z                  NaN                  NaN
# ...

# %%
reviews.loc[:, ["Reviews Rating", "Reviews Rating"]]
# Out:
#         Reviews Rating  Reviews Rating
# Sl.No.
# 1                  5.0             5.0
# 2                  5.0             5.0
# ...                ...             ...
# 2889               5.0             5.0
# 2890               5.0             5.0
#
# [2890 rows x 2 columns]

# %%
reviews.set_index("Name")
# Out:
#                                                                    Brand  \
# Name
# Ecco Domani174 Pinot Grigio - 750ml Bottle                         Gallo
# Fresh Craft174 Mango Citrus - 4pk / 250ml Bottle         Fresh Craft Co.
# ...                                                                  ...
# Vintage Wine Estates Kevin O'Leary's Select Res...  Vintage Wine Estates
# Vintage Wine Estates Kevin O'Leary's Select Res...  Vintage Wine Estates
#
#                                                       Reviews Date Added  \
# Name
# Ecco Domani174 Pinot Grigio - 750ml Bottle          2018-01-09T13:24:04Z
# Fresh Craft174 Mango Citrus - 4pk / 250ml Bottle    2018-01-09T17:31:52Z
# ...                                                                  ...
# Vintage Wine Estates Kevin O'Leary's Select Res...  2017-11-15T17:05:21Z
# Vintage Wine Estates Kevin O'Leary's Select Res...  2017-09-25T16:31:30Z
#
# ...

# %% [markdown]
# <p style= "color : Yellow; font-size:45px"> Conditonal Selection</p>

# %%
reviews.Brand == "Gallo"
# Out:
# Sl.No.
# 1        True
# 2       False
#         ...
# 2889    False
# 2890    False
# Name: Brand, Length: 2890, dtype: bool

# %%
reviews.loc[reviews.Brand == "Gallo"]
# Out:
#         Brand                                           Name  \
# Sl.No.
# 1       Gallo     Ecco Domani174 Pinot Grigio - 750ml Bottle
# 7       Gallo            Apothic174 Red Blend - 750ml Bottle
# ...       ...                                            ...
# 183     Gallo  Starborough174 Sauvignon Blanc - 750ml Bottle
# 265     Gallo   Barefoot174 Moscato White Wine - 1.5l Bottle
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                  1.0
# 7       2018-01-09T21:14:31Z                  NaN                  1.0
# ...                      ...                  ...                  ...
# 183     2018-01-10T05:58:03Z                  NaN                  NaN
# 265     2017-09-20T01:18:35Z                 True                  NaN
#
#         Reviews Rating                                       Reviews Text  \
# Sl.No.
# ...

# %%
reviews.loc[reviews.Brand == "Gallo"].set_index("Name")
# Out:
#                                                Brand    Reviews Date Added  \
# Name
# Ecco Domani174 Pinot Grigio - 750ml Bottle     Gallo  2018-01-09T13:24:04Z
# Apothic174 Red Blend - 750ml Bottle            Gallo  2018-01-09T21:14:31Z
# ...                                              ...                   ...
# Starborough174 Sauvignon Blanc - 750ml Bottle  Gallo  2018-01-10T05:58:03Z
# Barefoot174 Moscato White Wine - 1.5l Bottle   Gallo  2017-09-20T01:18:35Z
#
#                                               Reviews do Recommend  \
# Name
# Ecco Domani174 Pinot Grigio - 750ml Bottle                    True
# Apothic174 Red Blend - 750ml Bottle                            NaN
# ...                                                            ...
# Starborough174 Sauvignon Blanc - 750ml Bottle                  NaN
# Barefoot174 Moscato White Wine - 1.5l Bottle                  True
#
#                                                Reviews Num Helpful  \
# Name
# ...

# %%
reviews.loc[(reviews.Brand == "Gallo") | (reviews.Brand == "1000 Stories")]
# Out:
#                Brand                                           Name  \
# Sl.No.
# 1              Gallo     Ecco Domani174 Pinot Grigio - 750ml Bottle
# 3       1000 Stories       1000 Stories174 Zinfandel - 750ml Bottle
# ...              ...                                            ...
# 183            Gallo  Starborough174 Sauvignon Blanc - 750ml Bottle
# 265            Gallo   Barefoot174 Moscato White Wine - 1.5l Bottle
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                  1.0
# 3       2018-01-09T17:31:51Z                 True                  NaN
# ...                      ...                  ...                  ...
# 183     2018-01-10T05:58:03Z                  NaN                  NaN
# 265     2017-09-20T01:18:35Z                 True                  NaN
#
#         Reviews Rating                                       Reviews Text  \
# Sl.No.
# ...

# %%
reviews.loc[(reviews.Brand == "Gallo") | (reviews.Brand == "1000 Stories")]
# Out:
#                Brand                                           Name  \
# Sl.No.
# 1              Gallo     Ecco Domani174 Pinot Grigio - 750ml Bottle
# 3       1000 Stories       1000 Stories174 Zinfandel - 750ml Bottle
# ...              ...                                            ...
# 183            Gallo  Starborough174 Sauvignon Blanc - 750ml Bottle
# 265            Gallo   Barefoot174 Moscato White Wine - 1.5l Bottle
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                  1.0
# 3       2018-01-09T17:31:51Z                 True                  NaN
# ...                      ...                  ...                  ...
# 183     2018-01-10T05:58:03Z                  NaN                  NaN
# 265     2017-09-20T01:18:35Z                 True                  NaN
#
#         Reviews Rating                                       Reviews Text  \
# Sl.No.
# ...

# %%
reviews.loc[reviews.Brand.isin(['Gallo', '1000 Stories'])]
# Out:
#                Brand                                           Name  \
# Sl.No.
# 1              Gallo     Ecco Domani174 Pinot Grigio - 750ml Bottle
# 3       1000 Stories       1000 Stories174 Zinfandel - 750ml Bottle
# ...              ...                                            ...
# 183            Gallo  Starborough174 Sauvignon Blanc - 750ml Bottle
# 265            Gallo   Barefoot174 Moscato White Wine - 1.5l Bottle
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                  1.0
# 3       2018-01-09T17:31:51Z                 True                  NaN
# ...                      ...                  ...                  ...
# 183     2018-01-10T05:58:03Z                  NaN                  NaN
# 265     2017-09-20T01:18:35Z                 True                  NaN
#
#         Reviews Rating                                       Reviews Text  \
# Sl.No.
# ...

# %%
reviews.loc[reviews["Reviews do Recommend"].isnull()]
# Out:
#                        Brand  \
# Sl.No.
# 7                      Gallo
# 8                      Gallo
# ...                      ...
# 2889    Vintage Wine Estates
# 2890    Vintage Wine Estates
#
#                                                      Name  \
# Sl.No.
# 7                     Apothic174 Red Blend - 750ml Bottle
# 8                     Apothic174 Red Blend - 750ml Bottle
# ...                                                   ...
# 2889    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2890    Vintage Wine Estates Kevin O'Leary's Select Re...
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 7       2018-01-09T21:14:31Z                  NaN                  1.0
# 8       2017-12-15T00:02:24Z                  NaN                  1.0
# ...                      ...                  ...                  ...
# 2889    2017-11-15T17:05:21Z                  NaN                  NaN
# ...

# %%
reviews['Reviews Num Helpful'] = 5555
reviews
# Out:
#                        Brand  \
# Sl.No.
# 1                      Gallo
# 2            Fresh Craft Co.
# ...                      ...
# 2889    Vintage Wine Estates
# 2890    Vintage Wine Estates
#
#                                                      Name  \
# Sl.No.
# 1              Ecco Domani174 Pinot Grigio - 750ml Bottle
# 2        Fresh Craft174 Mango Citrus - 4pk / 250ml Bottle
# ...                                                   ...
# 2889    Vintage Wine Estates Kevin O'Leary's Select Re...
# 2890    Vintage Wine Estates Kevin O'Leary's Select Re...
#
#           Reviews Date Added Reviews do Recommend  Reviews Num Helpful  \
# Sl.No.
# 1       2018-01-09T13:24:04Z                 True                 5555
# 2       2018-01-09T17:31:52Z                 True                 5555
# ...                      ...                  ...                  ...
# 2889    2017-11-15T17:05:21Z                  NaN                 5555
# ...

# %% [markdown]
# nokte injast ke age az loc estefade mikoni , be label kar dare , harchi label bood che row che column estenad mikoni
# yani masalan age row to hast "test1", "test2" vaghti mikhai behesh erja koni bayad ein hamin ro biari to query_text
# ----------------------------------
# vali age az iloc estefade mikoni be andis (indice) kar dare, dg mohem nist lable chi hast , mohem andis oon hast, eyne ye list ke vaghti mikhaim be
# onsor 3 eshare konim migim masalan listo[2]
